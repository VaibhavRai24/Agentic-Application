# %%
from typing import TypedDict, Annotated, Optional
from langgraph.graph import add_messages, StateGraph, END
from langchain_groq import ChatGroq
from dotenv import load_dotenv
from langchain_community.tools.tavily_search import TavilySearchResults
from langgraph.checkpoint.memory import MemorySaver
from uuid import uuid4
import json

load_dotenv()

model = ChatGroq(model="llama-3.1-8b-instant")

# %%
search_tool = TavilySearchResults(max_results=4)

tools = [search_tool]

memory = MemorySaver()

# %%
llm_with_tools = model.bind_tools(tools=tools)

# %%
from langchain_core.messages import AIMessage, HumanMessage, ToolMessage

class State(TypedDict):
    messages: Annotated[list, add_messages]

async def model(state: State):
    result = await llm_with_tools.ainvoke(state["messages"])
    return {
        "messages": [result], 
    }

async def tools_router(state: State):
    last_message = state["messages"][-1]

    if(hasattr(last_message, "tool_calls") and len(last_message.tool_calls) > 0):
        return "tool_node"
    else: 
        return END
    
async def tool_node(state):
    """Custom tool node that handles tool calls from the LLM."""
    # Get the tool calls from the last message
    tool_calls = state["messages"][-1].tool_calls
    
    # Initialize list to store tool messages
    tool_messages = []
    
    # Process each tool call
    for tool_call in tool_calls:
        tool_name = tool_call["name"]
        tool_args = tool_call["args"]
        tool_id = tool_call["id"]
        
        # Handle the search tool
        if tool_name == "tavily_search_results_json":
            # Execute the search tool with the provided arguments
            search_results = await search_tool.ainvoke(tool_args)
            
            # Create a ToolMessage for this result
            tool_message = ToolMessage(
                content=str(search_results),
                tool_call_id=tool_id,
                name=tool_name
            )
            
            tool_messages.append(tool_message)
    
    # Add the tool messages to the state
    return {"messages": tool_messages}

graph_builder = StateGraph(State)

graph_builder.add_node("model", model)
graph_builder.add_node("tool_node", tool_node)
graph_builder.set_entry_point("model")

graph_builder.add_conditional_edges("model", tools_router)
graph_builder.add_edge("tool_node", "model")

graph = graph_builder.compile(checkpointer=memory)

# %%
from IPython.display import Image, display
from langchain_core.runnables.graph import MermaidDrawMethod

display(
    Image(
        graph.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API
        )
    )
)

# %%
config = {
    "configurable": {
        "thread_id": 5
    }
}

response = await graph.ainvoke({
    "messages": [HumanMessage(content="When is the next spaceX launch?")], 
}, config=config)

response
# Out:
# {'messages': [HumanMessage(content='When is the next spaceX launch?', additional_kwargs={}, response_metadata={}, id='e1cfae5b-ac16-473b-8664-ab6ab6211d91'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'h1gf1jvh2', 'function': {'arguments': '{"query":"SpaceX next launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 286, 'total_tokens': 308, 'completion_time': 0.145001091, 'prompt_time': 0.028613479, 'queue_time': 0.084962201, 'total_time': 0.17361457}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_510c177af0', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--6d9d59b1-3152-4fae-bd92-b4983604dead-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'SpaceX next launch date'}, 'id': 'h1gf1jvh2', 'type': 'tool_call'}], usage_metadata={'input_tokens': 286, 'output_tokens': 22, 'total_tokens': 308}),
#   ToolMessage(content='[{\'title\': \'Space Launch Schedule & Live Videos: Stream Rockets Launches\', \'url\': \'https://www.spacelaunchschedule.com/\', \'content\': \'Go For Launch \\n\\n Wed • Aug 20th, 2025\\n\\n 5:13 PM UTC \\n\\n Baikonur Cosmodrome, Republic of Kazakhstan \\n\\n (USSF-36)Falcon 9 Block 5 ---------------------------------------\\n### SpaceX\\n\\n Date/Time TBD \\n\\n Projected To Launch\\n\\n Thu • Aug 21st, 2025 \\n\\n Kennedy Space Center, FL, USA \\n\\n\\n   Vulcan\\n   New Glenn\\n   New Shepard\\n\\n### View The Rocket Launch Schedule\\n\\n### By Location\', \'score\': 0.8893851}, {\'title\': \'SpaceX Launch Schedule - RocketLaunch.Live\', \'url\': \'https://www.rocketlaunch.live/?filter=spacex\', \'content\': \'| Selected |\\n| --- |\\n| Providers | all |\\n| Locations | all |\\n| Launches | 25 |\\n\\n### Next SpaceX Launch\\n\\nJUL 30\\n\\n03:30 \\n\\n#### Starlink (10-29) Mission (Falcon 9)")\\n\\n#### Falcon 9\\n\\nSpaceX\\n\\n SLC-40, Cape Canaveral SFS\\n\\nFlorida, United States\\n\\n  \\n\\nOn launch day, head back here to watch the live stream! (if available)\\n\\n  \\n\\nSeries: SpaceX Starlink\\n\\nJUL 29\\n\\nJUL 30\\n\\n03:30 \\n\\n#### Starlink (10-29) Mission (Falcon 9)")\\n\\n#### Falcon 9\\n\\nSpaceX\\n\\n SLC-40, Cape Canaveral SFS\\n\\nFlorida, United States\', \'score\': 0.88799405}, {\'title\': \'SpaceX Launch Manifest - Next Spaceflight\', \'url\': \'https://nextspaceflight.com/launches/agency/upcoming/1/\', \'content\': \'SpaceX Launch Manifest\\n\\n===============\\n\\nNEXT SPACEFLIGHTLaunchesEventsStarshipRocketsReuseLocations\\n\\nNEXT SPACEFLIGHTImage 1 LaunchesImage 2 EventsImage 3 StarshipImage 4 RocketsImage 5 ReuseImage 6 Locations\\n\\n### SpaceX Manifest\\n\\nUpcomingPast\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Project Kuiper (KF-01)\\n\\n ASOG \\n\\n Inflight | Launch Wed Jul 16, 2025 06:30 UTC\\n\\nSLC-40, Cape Canaveral SFS, Florida, USA \\n\\nDetailsWatch\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Starlink Group 17-3\\n\\n OCISLY [...] Sat Jul 19, 2025 02:08 UTC\\n\\nSLC-4E, Vandenberg SFB, California, USA \\n\\nDetails\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Starlink Group 17-2\\n\\n OCISLY \\n\\nMon Jul 21, 2025 02:09 UTC\\n\\nSLC-4E, Vandenberg SFB, California, USA \\n\\nDetails\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | O3b mPOWER 9 & 10\\n\\n ASDS \\n\\nMon Jul 21, 2025 21:00 UTC\\n\\nSLC-40, Cape Canaveral SFS, Florida, USA \\n\\nDetails\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | TRACERS & Others\\n\\n LZ-4 \\n\\nTue Jul 22, 2025 18:05 UTC\\n\\nSLC-4E, Vandenberg SFB, California, USA [...] Details\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | SpaceX Crew-11\\n\\n LZ-1 \\n\\n Shannon \\n\\nThu Jul 31, 2025 16:09 UTC\\n\\nLC-39A, Kennedy Space Center, Florida, USA \\n\\nDetails\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Tranche 1 Transport Layer B\\n\\n NET July, 2025 \\n\\nSLC-4E, Vandenberg SFB, California, USA \\n\\nDetails\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Nusantara Lima\\n\\n NET August, 2025 \\n\\nSLC-40 or LC-39A, Florida, USA \\n\\nDetails\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | CRS SpX-33\\n\\n LZ-1 \\n\\n Shannon \\n\\n NET August, 2025\', \'score\': 0.8682137}, {\'title\': \'Next Spaceflight | Rocket Launch Schedule\', \'url\': \'https://nextspaceflight.com/\', \'content\': \'Next Spaceflight | Rocket Launch Schedule\\n\\n===============\\n\\nNEXT SPACEFLIGHTLaunchesEventsStarshipRocketsReuseLocations\\n\\nNEXT SPACEFLIGHTImage 1 LaunchesImage 2 EventsImage 3 StarshipImage 4 RocketsImage 5 ReuseImage 6 Locations\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Starlink Group 17-4\\n\\n OCISLY \\n\\nTue Aug 12, 2025 02:05 UTC\\n\\nSLC-4E, Vandenberg SFB, California, USA \\n\\nDetailsWatch\\n\\n ULA \\n\\n##### Vulcan VC4S | USSF-106 (NTS-3 & Others)\\n\\nTue Aug 12, 2025 23:59 UTC\', \'score\': 0.86024034}]', name='tavily_search_results_json', id='3259e58f-66f2-450d-b5fb-6fccd232468b', tool_call_id='h1gf1jvh2'),
#   AIMessage(content='The next SpaceX launch appears to be the USSF-36 mission on August 20th, 2025, at 5:13 PM UTC, from the Baikonur Cosmodrome in Kazakhstan.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 43, 'prompt_tokens': 1543, 'total_tokens': 1586, 'completion_time': 0.08564681, 'prompt_time': 0.11496456, 'queue_time': 0.133668641, 'total_time': 0.20061137}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_510c177af0', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='run--34052dbf-82fa-4658-8b7f-3de1473e07fd-0', usage_metadata={'input_tokens': 1543, 'output_tokens': 43, 'total_tokens': 1586})]}

# %%
config = {
    "configurable": {
        "thread_id": 8
    }
}

# Use async for to iterate over the async generator
async for event in graph.astream_events({
    "messages": [HumanMessage(content="When is the next spacex launch?")],
}, config=config, version="v2"):
    print(event)
# Out:
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={})]}}, 'name': 'LangGraph', 'tags': [], 'run_id': '258b23b8-bd07-4892-83f3-19ca8db2202a', 'metadata': {'thread_id': 8}, 'parent_ids': []}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='fe8793a6-dc65-4160-86d3-667da7016618')]}}, 'name': 'model', 'tags': ['graph:step:1'], 'run_id': 'b1bdfb3d-5dc3-41ef-84f9-f7bd8f95cf96', 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:2bc4e3f9-6dd5-0ce5-2aa1-6376fb7354dd'}, 'parent_ids': ['258b23b8-bd07-4892-83f3-19ca8db2202a']}
# {'event': 'on_chat_model_start', 'data': {'input': {'messages': [[HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='fe8793a6-dc65-4160-86d3-667da7016618')]]}}, 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'run_id': '1e2fe9ea-b8f2-4c19-83f3-3aece3f121eb', 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:2bc4e3f9-6dd5-0ce5-2aa1-6376fb7354dd', 'checkpoint_ns': 'model:2bc4e3f9-6dd5-0ce5-2aa1-6376fb7354dd', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['258b23b8-bd07-4892-83f3-19ca8db2202a', 'b1bdfb3d-5dc3-41ef-84f9-f7bd8f95cf96']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--1e2fe9ea-b8f2-4c19-83f3-3aece3f121eb')}, 'run_id': '1e2fe9ea-b8f2-4c19-83f3-3aece3f121eb', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:2bc4e3f9-6dd5-0ce5-2aa1-6376fb7354dd', 'checkpoint_ns': 'model:2bc4e3f9-6dd5-0ce5-2aa1-6376fb7354dd', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['258b23b8-bd07-4892-83f3-19ca8db2202a', 'b1bdfb3d-5dc3-41ef-84f9-f7bd8f95cf96']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'abjfjmx2m', 'function': {'arguments': '{"query":"spacex next launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={}, id='run--1e2fe9ea-b8f2-4c19-83f3-3aece3f121eb', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'spacex next launch date'}, 'id': 'abjfjmx2m', 'type': 'tool_call'}], tool_call_chunks=[{'name': 'tavily_search_results_json', 'args': '{"query":"spacex next launch date"}', 'id': 'abjfjmx2m', 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': '1e2fe9ea-b8f2-4c19-83f3-3aece3f121eb', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:2bc4e3f9-6dd5-0ce5-2aa1-6376fb7354dd', 'checkpoint_ns': 'model:2bc4e3f9-6dd5-0ce5-2aa1-6376fb7354dd', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['258b23b8-bd07-4892-83f3-19ca8db2202a', 'b1bdfb3d-5dc3-41ef-84f9-f7bd8f95cf96']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_46fc01befd', 'service_tier': 'on_demand'}, id='run--1e2fe9ea-b8f2-4c19-83f3-3aece3f121eb', usage_metadata={'input_tokens': 286, 'output_tokens': 23, 'total_tokens': 309})}, 'run_id': '1e2fe9ea-b8f2-4c19-83f3-3aece3f121eb', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:2bc4e3f9-6dd5-0ce5-2aa1-6376fb7354dd', 'checkpoint_ns': 'model:2bc4e3f9-6dd5-0ce5-2aa1-6376fb7354dd', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['258b23b8-bd07-4892-83f3-19ca8db2202a', 'b1bdfb3d-5dc3-41ef-84f9-f7bd8f95cf96']}
# {'event': 'on_chat_model_end', 'data': {'output': AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'abjfjmx2m', 'function': {'arguments': '{"query":"spacex next launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_46fc01befd', 'service_tier': 'on_demand'}, id='run--1e2fe9ea-b8f2-4c19-83f3-3aece3f121eb', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'spacex next launch date'}, 'id': 'abjfjmx2m', 'type': 'tool_call'}], usage_metadata={'input_tokens': 286, 'output_tokens': 23, 'total_tokens': 309}), 'input': {'messages': [[HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='fe8793a6-dc65-4160-86d3-667da7016618')]]}}, 'run_id': '1e2fe9ea-b8f2-4c19-83f3-3aece3f121eb', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:2bc4e3f9-6dd5-0ce5-2aa1-6376fb7354dd', 'checkpoint_ns': 'model:2bc4e3f9-6dd5-0ce5-2aa1-6376fb7354dd', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7, 'LANGSMITH_TRACING': 'true', 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'LANGSMITH_PROJECT': 'pr-impressionable-lung-64'}, 'parent_ids': ['258b23b8-bd07-4892-83f3-19ca8db2202a', 'b1bdfb3d-5dc3-41ef-84f9-f7bd8f95cf96']}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='fe8793a6-dc65-4160-86d3-667da7016618'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'abjfjmx2m', 'function': {'arguments': '{"query":"spacex next launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_46fc01befd', 'service_tier': 'on_demand'}, id='run--1e2fe9ea-b8f2-4c19-83f3-3aece3f121eb', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'spacex next launch date'}, 'id': 'abjfjmx2m', 'type': 'tool_call'}], usage_metadata={'input_tokens': 286, 'output_tokens': 23, 'total_tokens': 309})]}}, 'name': 'tools_router', 'tags': ['seq:step:3'], 'run_id': 'aeee1a9f-166f-4d92-be4c-a1ad791cca4b', 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:2bc4e3f9-6dd5-0ce5-2aa1-6376fb7354dd'}, 'parent_ids': ['258b23b8-bd07-4892-83f3-19ca8db2202a', 'b1bdfb3d-5dc3-41ef-84f9-f7bd8f95cf96']}
# {'event': 'on_chain_end', 'data': {'output': 'tool_node', 'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='fe8793a6-dc65-4160-86d3-667da7016618'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'abjfjmx2m', 'function': {'arguments': '{"query":"spacex next launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_46fc01befd', 'service_tier': 'on_demand'}, id='run--1e2fe9ea-b8f2-4c19-83f3-3aece3f121eb', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'spacex next launch date'}, 'id': 'abjfjmx2m', 'type': 'tool_call'}], usage_metadata={'input_tokens': 286, 'output_tokens': 23, 'total_tokens': 309})]}}, 'run_id': 'aeee1a9f-166f-4d92-be4c-a1ad791cca4b', 'name': 'tools_router', 'tags': ['seq:step:3'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:2bc4e3f9-6dd5-0ce5-2aa1-6376fb7354dd', 'LANGSMITH_TRACING': 'true', 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'LANGSMITH_PROJECT': 'pr-impressionable-lung-64'}, 'parent_ids': ['258b23b8-bd07-4892-83f3-19ca8db2202a', 'b1bdfb3d-5dc3-41ef-84f9-f7bd8f95cf96']}
# {'event': 'on_chain_stream', 'run_id': 'b1bdfb3d-5dc3-41ef-84f9-f7bd8f95cf96', 'name': 'model', 'tags': ['graph:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:2bc4e3f9-6dd5-0ce5-2aa1-6376fb7354dd'}, 'data': {'chunk': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'abjfjmx2m', 'function': {'arguments': '{"query":"spacex next launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_46fc01befd', 'service_tier': 'on_demand'}, id='run--1e2fe9ea-b8f2-4c19-83f3-3aece3f121eb', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'spacex next launch date'}, 'id': 'abjfjmx2m', 'type': 'tool_call'}], usage_metadata={'input_tokens': 286, 'output_tokens': 23, 'total_tokens': 309})]}}, 'parent_ids': ['258b23b8-bd07-4892-83f3-19ca8db2202a']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'abjfjmx2m', 'function': {'arguments': '{"query":"spacex next launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_46fc01befd', 'service_tier': 'on_demand'}, id='run--1e2fe9ea-b8f2-4c19-83f3-3aece3f121eb', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'spacex next launch date'}, 'id': 'abjfjmx2m', 'type': 'tool_call'}], usage_metadata={'input_tokens': 286, 'output_tokens': 23, 'total_tokens': 309})]}, 'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='fe8793a6-dc65-4160-86d3-667da7016618')]}}, 'run_id': 'b1bdfb3d-5dc3-41ef-84f9-f7bd8f95cf96', 'name': 'model', 'tags': ['graph:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:2bc4e3f9-6dd5-0ce5-2aa1-6376fb7354dd', 'LANGSMITH_TRACING': 'true', 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'LANGSMITH_PROJECT': 'pr-impressionable-lung-64'}, 'parent_ids': ['258b23b8-bd07-4892-83f3-19ca8db2202a']}
# {'event': 'on_chain_stream', 'run_id': '258b23b8-bd07-4892-83f3-19ca8db2202a', 'name': 'LangGraph', 'tags': [], 'metadata': {'thread_id': 8}, 'data': {'chunk': {'model': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'abjfjmx2m', 'function': {'arguments': '{"query":"spacex next launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_46fc01befd', 'service_tier': 'on_demand'}, id='run--1e2fe9ea-b8f2-4c19-83f3-3aece3f121eb', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'spacex next launch date'}, 'id': 'abjfjmx2m', 'type': 'tool_call'}], usage_metadata={'input_tokens': 286, 'output_tokens': 23, 'total_tokens': 309})]}}}, 'parent_ids': []}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='fe8793a6-dc65-4160-86d3-667da7016618'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'abjfjmx2m', 'function': {'arguments': '{"query":"spacex next launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_46fc01befd', 'service_tier': 'on_demand'}, id='run--1e2fe9ea-b8f2-4c19-83f3-3aece3f121eb', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'spacex next launch date'}, 'id': 'abjfjmx2m', 'type': 'tool_call'}], usage_metadata={'input_tokens': 286, 'output_tokens': 23, 'total_tokens': 309})]}}, 'name': 'tool_node', 'tags': ['graph:step:2'], 'run_id': '33cb5d8b-db8c-4c98-8ddf-58b171a47907', 'metadata': {'thread_id': 8, 'langgraph_step': 2, 'langgraph_node': 'tool_node', 'langgraph_triggers': ('branch:to:tool_node',), 'langgraph_path': ('__pregel_pull', 'tool_node'), 'langgraph_checkpoint_ns': 'tool_node:afe239b9-0829-196c-66a5-e15f7ac429ac'}, 'parent_ids': ['258b23b8-bd07-4892-83f3-19ca8db2202a']}
# {'event': 'on_tool_start', 'data': {'input': {'query': 'spacex next launch date'}}, 'name': 'tavily_search_results_json', 'tags': ['seq:step:1'], 'run_id': 'd12406fd-b473-4cd7-adc6-d6d8cf8be172', 'metadata': {'thread_id': 8, 'langgraph_step': 2, 'langgraph_node': 'tool_node', 'langgraph_triggers': ('branch:to:tool_node',), 'langgraph_path': ('__pregel_pull', 'tool_node'), 'langgraph_checkpoint_ns': 'tool_node:afe239b9-0829-196c-66a5-e15f7ac429ac', 'checkpoint_ns': 'tool_node:afe239b9-0829-196c-66a5-e15f7ac429ac'}, 'parent_ids': ['258b23b8-bd07-4892-83f3-19ca8db2202a', '33cb5d8b-db8c-4c98-8ddf-58b171a47907']}
# {'event': 'on_tool_end', 'data': {'output': [{'title': 'SpaceX - Launches', 'url': 'https://www.spacex.com/launches/', 'content': '| Mission Clear Starship Flight Tests Human Spaceflight Space Station Resupply Science Commercial / International Rideshare Program National Security Starlink Direct to Cell Starman | Vehicle Clear Falcon 9 Falcon Heavy Starship Falcon 1 | Launch Site Clear LC-39A, Florida SLC-40, Florida SLC-4E, California Starbase, Texas Omelek Island | Return Site Clear Droneship Landing Zone Mechazilla Expended Landing Zone / Expended Landing Zone / Droneship | Launch Date Clear 2025 2024 2023 2022 2021 2020 2019 2018 2017 2016 2015 2014 2013 2012 2011 2010 2009 2008 2007 2006 | | Starlink Mission | Falcon 9 | SLC-40, Florida | Droneship | July 29, 2025 | | Starlink Mission | Falcon 9 | SLC-40, Florida | Droneship | July 26, 2025 |', 'score': 0.98531}, {'title': 'Launch Schedule - Spaceflight Now', 'url': 'https://spaceflightnow.com/launch-schedule/', 'content': '*   [[ August 10, 2025 ] SpaceX launches Amazon’s Project Kuiper satellites on fifth scheduled attempt Falcon 9](https://spaceflightnow.com/2025/08/10/live-coverage-spacex-falcon-9-to-make-another-attempt-to-launch-amazon-project-kuiper-mission/ "SpaceX launches Amazon’s Project Kuiper satellites on fifth scheduled attempt") A SpaceX Falcon 9 rocket will launch the eighth mission of the X-37B Orbital Test Vehicle (OTV-8), a cargo spaceplane built by Boeing on behalf of the U.S. Space Force in cooperation with the Air Force Rapid Capabilities Office. A SpaceX Falcon 9 rocket will launch a Cygnus spacecraft from Northrop Grumman on a resupply mission to the International Space Station. *   Image 3SpaceX launches 28 Starlink satellites on Falcon 9 rocket from Cape Canaveral August 14, 2025   *   Image 4ULA launches Vulcan rocket on first Space Force mission August 13, 2025  ', 'score': 0.98529}, {'title': 'SpaceX Launch Schedule - RocketLaunch.Live', 'url': 'https://www.rocketlaunch.live/?filter=spacex', 'content': '*   - [x] CAS Space   *   - [x] i-Space   *   - [x] Xichang Satellite Launch Center   *   - [x] Taiyuan Satellite Launch Center   *   - [x] Jiuquan Satellite Launch Center   *   - [x] Wenchang Satellite Launch Center   *   - [x] Space One   *   - [x] Astra Space   *    North Korea - [x] Sohae Satellite Launching Station   *    MAR 31  Starlink-243 (6-80) Mission (Falcon 9)")   *    MAR 26  Starlink-242 (11-7) Mission (Falcon 9)")   *    MAR 18  Starlink-241 (12-25) Mission (Falcon 9)")   *    MAR 15  Starlink-240 (12-16) Mission (Falcon 9)")   *    MAR 13  Starlink-239 (12-21) Mission (Falcon 9)")   *    MAR 03  Starlink-238 (12-20) Mission (Falcon 9)")   Mission The mission will also launch the FLIP lunar rover.") #### GO-1 Mission")', 'score': 0.98351}, {'title': 'Next Spaceflight | Rocket Launch Schedule', 'url': 'https://nextspaceflight.com/', 'content': 'Next Spaceflight | Rocket Launch Schedule ##### Long March 4C | Unknown Payload Sun Aug 17, 2025 09:05 UTC LC-3, Xichang Satellite Launch Center, China  Sun Aug 17, 2025 14:15 UTC LC-9A, Taiyuan Satellite Launch Center, China  Mon Aug 18, 2025 15:44 UTC Image 8: Get it on the App Store Image 9: FAA approves Starship Flight 10 after mishap probe, eyes August 24 launch ##### FAA approves Starship Flight 10 after mishap probe, eyes August 24 launch Image 10: East Coast sees major progress for future operations at the Cape Image 11: Skyrora weighs options on the path to the UK’s first vertical launch ##### Skyrora weighs options on the path to the UK’s first vertical launch', 'score': 0.9769}], 'input': {'query': 'spacex next launch date'}}, 'run_id': 'd12406fd-b473-4cd7-adc6-d6d8cf8be172', 'name': 'tavily_search_results_json', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 2, 'langgraph_node': 'tool_node', 'langgraph_triggers': ('branch:to:tool_node',), 'langgraph_path': ('__pregel_pull', 'tool_node'), 'langgraph_checkpoint_ns': 'tool_node:afe239b9-0829-196c-66a5-e15f ...
# {'event': 'on_chain_stream', 'run_id': '33cb5d8b-db8c-4c98-8ddf-58b171a47907', 'name': 'tool_node', 'tags': ['graph:step:2'], 'metadata': {'thread_id': 8, 'langgraph_step': 2, 'langgraph_node': 'tool_node', 'langgraph_triggers': ('branch:to:tool_node',), 'langgraph_path': ('__pregel_pull', 'tool_node'), 'langgraph_checkpoint_ns': 'tool_node:afe239b9-0829-196c-66a5-e15f7ac429ac'}, 'data': {'chunk': {'messages': [ToolMessage(content='[{\'title\': \'SpaceX - Launches\', \'url\': \'https://www.spacex.com/launches/\', \'content\': \'| Mission Clear Starship Flight Tests Human Spaceflight Space Station Resupply Science Commercial / International Rideshare Program National Security Starlink Direct to Cell Starman | Vehicle Clear Falcon 9 Falcon Heavy Starship Falcon 1 | Launch Site Clear LC-39A, Florida SLC-40, Florida SLC-4E, California Starbase, Texas Omelek Island | Return Site Clear Droneship Landing Zone Mechazilla Expended Landing Zone / Expended Landing Zone / Droneship | Launch Date Clear 2025 2024 2023 2022 2021 2020 2019 2018 2017 2016 2015 2014 2013 2012 2011 2010 2009 2008 2007 2006 | | Starlink Mission | Falcon 9 | SLC-40, Florida | Droneship | July 29, 2025 | | Starlink Mission | Falcon 9 | SLC-40, Florida | Droneship | July 26, 2025 |\', \'score\': 0.98531}, {\'title\': \'Launch Schedule - Spaceflight Now\', \'url\': \'https://spaceflightnow.com/launch-schedule/\', \'content\': \'*   [[ August 10, 2025 ] SpaceX launches Amazon’s Project Kuiper satellites on fifth scheduled attempt Falcon 9](https://spaceflightnow.com/2025/08/10/live-coverage-spacex-falcon-9-to-make-another-attempt-to-launch-amazon-project-kuiper-mission/ "SpaceX launches Amazon’s Project Kuiper satellites on fifth scheduled attempt") A SpaceX Falcon 9 rocket will launch the eighth mission of the X-37B Orbital Test Vehicle (OTV-8), a cargo spaceplane built by Boeing on behalf of the U.S. Space Force in cooperation with the Air Force Rapid Capabilities Office. A SpaceX Falcon 9 rocket will launch a Cygnus spacecraft from Northrop Grumman on a resupply mission to the International Space Station. *   Image 3SpaceX launches 28 Starlink satellites on Falcon 9 rocket from Cape Canaveral August 14, 2025   *   Image 4ULA launches Vulcan rocket on first Space Force mission August 13, 2025  \', \'score\': 0.98529}, {\'title\': \'SpaceX Launch Schedule - RocketLaunch.Live\', \'url\': \'https://www.rocketlaunch.live/?filter=spacex\', \'content\': \'*   - [x] CAS Space   *   - [x] i-Space   *   - [x] Xichang Satellite Launch Center   *   - [x] Taiyuan Satellite Launch Center   *   - [x] Jiuquan Satellite Launch Center   *   - [x] Wenchang Satellite Launch Center   *   - [x] Space One   *   - [x] Astra Space   *    North Korea - [x] Sohae Satellite Launching Station   *    MAR 31  Starlink-243 (6-80) Mission (Falcon 9)")   *    MAR 26  Starlink-242 (11-7) Mission (Falcon 9)")   *    MAR 18  Starlink-241 (12-25) Mission (Falcon 9)")   *    MAR 15  Starlink-240 (12-16) Mission (Falcon 9)")   *    MAR 13  Starlink-239 (12-21) Mission (Falcon 9)")   *    MAR 03  Starlink-238 (12-20) Mission (Falcon 9)")   Mission The mission will also launch the FLIP lunar rover.") #### GO-1 Mission")\', \'score\': 0.98351}, {\'title\': \'Next Spaceflight | Rocket Launch Schedule\', \'url\': \'https://nextspaceflight.com/\', \'content\': \'Next Spaceflight | Rocket Launch Schedule ##### Long March 4C | Unknown Payload Sun Aug 17, 2025 09:05 UTC LC-3, Xichang Satellite Launch Center, China  Sun Aug 17, 2025 14:15 UTC LC-9A, Taiyuan Satellite Launch Center, China  Mon Aug 18, 2025 15:44 UTC Image 8: Get it on the App Store Image 9: FAA approves Starship Flight 10 after mishap probe, eyes August 24 launch ##### FAA approves Starship Flight 10 after mishap probe, eyes August 24 launch Image 10: East Coast sees major progress for future operations at the Cape Image 11: Skyrora weighs options on the path to the UK’s first vertical launch ##### Skyrora weighs options on the path to the UK’s fir ...
# {'event': 'on_chain_end', 'data': {'output': {'messages': [ToolMessage(content='[{\'title\': \'SpaceX - Launches\', \'url\': \'https://www.spacex.com/launches/\', \'content\': \'| Mission Clear Starship Flight Tests Human Spaceflight Space Station Resupply Science Commercial / International Rideshare Program National Security Starlink Direct to Cell Starman | Vehicle Clear Falcon 9 Falcon Heavy Starship Falcon 1 | Launch Site Clear LC-39A, Florida SLC-40, Florida SLC-4E, California Starbase, Texas Omelek Island | Return Site Clear Droneship Landing Zone Mechazilla Expended Landing Zone / Expended Landing Zone / Droneship | Launch Date Clear 2025 2024 2023 2022 2021 2020 2019 2018 2017 2016 2015 2014 2013 2012 2011 2010 2009 2008 2007 2006 | | Starlink Mission | Falcon 9 | SLC-40, Florida | Droneship | July 29, 2025 | | Starlink Mission | Falcon 9 | SLC-40, Florida | Droneship | July 26, 2025 |\', \'score\': 0.98531}, {\'title\': \'Launch Schedule - Spaceflight Now\', \'url\': \'https://spaceflightnow.com/launch-schedule/\', \'content\': \'*   [[ August 10, 2025 ] SpaceX launches Amazon’s Project Kuiper satellites on fifth scheduled attempt Falcon 9](https://spaceflightnow.com/2025/08/10/live-coverage-spacex-falcon-9-to-make-another-attempt-to-launch-amazon-project-kuiper-mission/ "SpaceX launches Amazon’s Project Kuiper satellites on fifth scheduled attempt") A SpaceX Falcon 9 rocket will launch the eighth mission of the X-37B Orbital Test Vehicle (OTV-8), a cargo spaceplane built by Boeing on behalf of the U.S. Space Force in cooperation with the Air Force Rapid Capabilities Office. A SpaceX Falcon 9 rocket will launch a Cygnus spacecraft from Northrop Grumman on a resupply mission to the International Space Station. *   Image 3SpaceX launches 28 Starlink satellites on Falcon 9 rocket from Cape Canaveral August 14, 2025   *   Image 4ULA launches Vulcan rocket on first Space Force mission August 13, 2025  \', \'score\': 0.98529}, {\'title\': \'SpaceX Launch Schedule - RocketLaunch.Live\', \'url\': \'https://www.rocketlaunch.live/?filter=spacex\', \'content\': \'*   - [x] CAS Space   *   - [x] i-Space   *   - [x] Xichang Satellite Launch Center   *   - [x] Taiyuan Satellite Launch Center   *   - [x] Jiuquan Satellite Launch Center   *   - [x] Wenchang Satellite Launch Center   *   - [x] Space One   *   - [x] Astra Space   *    North Korea - [x] Sohae Satellite Launching Station   *    MAR 31  Starlink-243 (6-80) Mission (Falcon 9)")   *    MAR 26  Starlink-242 (11-7) Mission (Falcon 9)")   *    MAR 18  Starlink-241 (12-25) Mission (Falcon 9)")   *    MAR 15  Starlink-240 (12-16) Mission (Falcon 9)")   *    MAR 13  Starlink-239 (12-21) Mission (Falcon 9)")   *    MAR 03  Starlink-238 (12-20) Mission (Falcon 9)")   Mission The mission will also launch the FLIP lunar rover.") #### GO-1 Mission")\', \'score\': 0.98351}, {\'title\': \'Next Spaceflight | Rocket Launch Schedule\', \'url\': \'https://nextspaceflight.com/\', \'content\': \'Next Spaceflight | Rocket Launch Schedule ##### Long March 4C | Unknown Payload Sun Aug 17, 2025 09:05 UTC LC-3, Xichang Satellite Launch Center, China  Sun Aug 17, 2025 14:15 UTC LC-9A, Taiyuan Satellite Launch Center, China  Mon Aug 18, 2025 15:44 UTC Image 8: Get it on the App Store Image 9: FAA approves Starship Flight 10 after mishap probe, eyes August 24 launch ##### FAA approves Starship Flight 10 after mishap probe, eyes August 24 launch Image 10: East Coast sees major progress for future operations at the Cape Image 11: Skyrora weighs options on the path to the UK’s first vertical launch ##### Skyrora weighs options on the path to the UK’s first vertical launch\', \'score\': 0.9769}]', name='tavily_search_results_json', tool_call_id='abjfjmx2m')]}, 'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='fe8793a6-dc65-4160-86d3-667da7016618'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'abjfj ...
# {'event': 'on_chain_stream', 'run_id': '258b23b8-bd07-4892-83f3-19ca8db2202a', 'name': 'LangGraph', 'tags': [], 'metadata': {'thread_id': 8}, 'data': {'chunk': {'tool_node': {'messages': [ToolMessage(content='[{\'title\': \'SpaceX - Launches\', \'url\': \'https://www.spacex.com/launches/\', \'content\': \'| Mission Clear Starship Flight Tests Human Spaceflight Space Station Resupply Science Commercial / International Rideshare Program National Security Starlink Direct to Cell Starman | Vehicle Clear Falcon 9 Falcon Heavy Starship Falcon 1 | Launch Site Clear LC-39A, Florida SLC-40, Florida SLC-4E, California Starbase, Texas Omelek Island | Return Site Clear Droneship Landing Zone Mechazilla Expended Landing Zone / Expended Landing Zone / Droneship | Launch Date Clear 2025 2024 2023 2022 2021 2020 2019 2018 2017 2016 2015 2014 2013 2012 2011 2010 2009 2008 2007 2006 | | Starlink Mission | Falcon 9 | SLC-40, Florida | Droneship | July 29, 2025 | | Starlink Mission | Falcon 9 | SLC-40, Florida | Droneship | July 26, 2025 |\', \'score\': 0.98531}, {\'title\': \'Launch Schedule - Spaceflight Now\', \'url\': \'https://spaceflightnow.com/launch-schedule/\', \'content\': \'*   [[ August 10, 2025 ] SpaceX launches Amazon’s Project Kuiper satellites on fifth scheduled attempt Falcon 9](https://spaceflightnow.com/2025/08/10/live-coverage-spacex-falcon-9-to-make-another-attempt-to-launch-amazon-project-kuiper-mission/ "SpaceX launches Amazon’s Project Kuiper satellites on fifth scheduled attempt") A SpaceX Falcon 9 rocket will launch the eighth mission of the X-37B Orbital Test Vehicle (OTV-8), a cargo spaceplane built by Boeing on behalf of the U.S. Space Force in cooperation with the Air Force Rapid Capabilities Office. A SpaceX Falcon 9 rocket will launch a Cygnus spacecraft from Northrop Grumman on a resupply mission to the International Space Station. *   Image 3SpaceX launches 28 Starlink satellites on Falcon 9 rocket from Cape Canaveral August 14, 2025   *   Image 4ULA launches Vulcan rocket on first Space Force mission August 13, 2025  \', \'score\': 0.98529}, {\'title\': \'SpaceX Launch Schedule - RocketLaunch.Live\', \'url\': \'https://www.rocketlaunch.live/?filter=spacex\', \'content\': \'*   - [x] CAS Space   *   - [x] i-Space   *   - [x] Xichang Satellite Launch Center   *   - [x] Taiyuan Satellite Launch Center   *   - [x] Jiuquan Satellite Launch Center   *   - [x] Wenchang Satellite Launch Center   *   - [x] Space One   *   - [x] Astra Space   *    North Korea - [x] Sohae Satellite Launching Station   *    MAR 31  Starlink-243 (6-80) Mission (Falcon 9)")   *    MAR 26  Starlink-242 (11-7) Mission (Falcon 9)")   *    MAR 18  Starlink-241 (12-25) Mission (Falcon 9)")   *    MAR 15  Starlink-240 (12-16) Mission (Falcon 9)")   *    MAR 13  Starlink-239 (12-21) Mission (Falcon 9)")   *    MAR 03  Starlink-238 (12-20) Mission (Falcon 9)")   Mission The mission will also launch the FLIP lunar rover.") #### GO-1 Mission")\', \'score\': 0.98351}, {\'title\': \'Next Spaceflight | Rocket Launch Schedule\', \'url\': \'https://nextspaceflight.com/\', \'content\': \'Next Spaceflight | Rocket Launch Schedule ##### Long March 4C | Unknown Payload Sun Aug 17, 2025 09:05 UTC LC-3, Xichang Satellite Launch Center, China  Sun Aug 17, 2025 14:15 UTC LC-9A, Taiyuan Satellite Launch Center, China  Mon Aug 18, 2025 15:44 UTC Image 8: Get it on the App Store Image 9: FAA approves Starship Flight 10 after mishap probe, eyes August 24 launch ##### FAA approves Starship Flight 10 after mishap probe, eyes August 24 launch Image 10: East Coast sees major progress for future operations at the Cape Image 11: Skyrora weighs options on the path to the UK’s first vertical launch ##### Skyrora weighs options on the path to the UK’s first vertical launch\', \'score\': 0.9769}]', name='tavily_search_results_json', id='4e3e82a8-524b-46da-9f41-8af16179ced9', tool_call_id='abjfjmx2m')]}}}, 'parent_ids': []}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='fe8793a6-dc65-4160-86d3-667da7016618'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'abjfjmx2m', 'function': {'arguments': '{"query":"spacex next launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_46fc01befd', 'service_tier': 'on_demand'}, id='run--1e2fe9ea-b8f2-4c19-83f3-3aece3f121eb', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'spacex next launch date'}, 'id': 'abjfjmx2m', 'type': 'tool_call'}], usage_metadata={'input_tokens': 286, 'output_tokens': 23, 'total_tokens': 309}), ToolMessage(content='[{\'title\': \'SpaceX - Launches\', \'url\': \'https://www.spacex.com/launches/\', \'content\': \'| Mission Clear Starship Flight Tests Human Spaceflight Space Station Resupply Science Commercial / International Rideshare Program National Security Starlink Direct to Cell Starman | Vehicle Clear Falcon 9 Falcon Heavy Starship Falcon 1 | Launch Site Clear LC-39A, Florida SLC-40, Florida SLC-4E, California Starbase, Texas Omelek Island | Return Site Clear Droneship Landing Zone Mechazilla Expended Landing Zone / Expended Landing Zone / Droneship | Launch Date Clear 2025 2024 2023 2022 2021 2020 2019 2018 2017 2016 2015 2014 2013 2012 2011 2010 2009 2008 2007 2006 | | Starlink Mission | Falcon 9 | SLC-40, Florida | Droneship | July 29, 2025 | | Starlink Mission | Falcon 9 | SLC-40, Florida | Droneship | July 26, 2025 |\', \'score\': 0.98531}, {\'title\': \'Launch Schedule - Spaceflight Now\', \'url\': \'https://spaceflightnow.com/launch-schedule/\', \'content\': \'*   [[ August 10, 2025 ] SpaceX launches Amazon’s Project Kuiper satellites on fifth scheduled attempt Falcon 9](https://spaceflightnow.com/2025/08/10/live-coverage-spacex-falcon-9-to-make-another-attempt-to-launch-amazon-project-kuiper-mission/ "SpaceX launches Amazon’s Project Kuiper satellites on fifth scheduled attempt") A SpaceX Falcon 9 rocket will launch the eighth mission of the X-37B Orbital Test Vehicle (OTV-8), a cargo spaceplane built by Boeing on behalf of the U.S. Space Force in cooperation with the Air Force Rapid Capabilities Office. A SpaceX Falcon 9 rocket will launch a Cygnus spacecraft from Northrop Grumman on a resupply mission to the International Space Station. *   Image 3SpaceX launches 28 Starlink satellites on Falcon 9 rocket from Cape Canaveral August 14, 2025   *   Image 4ULA launches Vulcan rocket on first Space Force mission August 13, 2025  \', \'score\': 0.98529}, {\'title\': \'SpaceX Launch Schedule - RocketLaunch.Live\', \'url\': \'https://www.rocketlaunch.live/?filter=spacex\', \'content\': \'*   - [x] CAS Space   *   - [x] i-Space   *   - [x] Xichang Satellite Launch Center   *   - [x] Taiyuan Satellite Launch Center   *   - [x] Jiuquan Satellite Launch Center   *   - [x] Wenchang Satellite Launch Center   *   - [x] Space One   *   - [x] Astra Space   *    North Korea - [x] Sohae Satellite Launching Station   *    MAR 31  Starlink-243 (6-80) Mission (Falcon 9)")   *    MAR 26  Starlink-242 (11-7) Mission (Falcon 9)")   *    MAR 18  Starlink-241 (12-25) Mission (Falcon 9)")   *    MAR 15  Starlink-240 (12-16) Mission (Falcon 9)")   *    MAR 13  Starlink-239 (12-21) Mission (Falcon 9)")   *    MAR 03  Starlink-238 (12-20) Mission (Falcon 9)")   Mission The mission will also launch the FLIP lunar rover.") #### GO-1 Mission")\', \'score\': 0.98351}, {\'title\': \'Next Spaceflight | Rocket Launch Schedule\', \'url\': \'https://nextspaceflight.com/\', \'content\': \'Next Spaceflight | Rocket Launch Schedule ##### Long March 4C | Unknown Payload Sun Aug 17, 2025 09:05 UTC LC-3, Xichang Satellite Launch Center, China  Sun Aug 17, 2025 14:15 UTC LC-9A, Taiyuan Satellite Launch Center, China  Mon  ...
# {'event': 'on_chat_model_start', 'data': {'input': {'messages': [[HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='fe8793a6-dc65-4160-86d3-667da7016618'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'abjfjmx2m', 'function': {'arguments': '{"query":"spacex next launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_46fc01befd', 'service_tier': 'on_demand'}, id='run--1e2fe9ea-b8f2-4c19-83f3-3aece3f121eb', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'spacex next launch date'}, 'id': 'abjfjmx2m', 'type': 'tool_call'}], usage_metadata={'input_tokens': 286, 'output_tokens': 23, 'total_tokens': 309}), ToolMessage(content='[{\'title\': \'SpaceX - Launches\', \'url\': \'https://www.spacex.com/launches/\', \'content\': \'| Mission Clear Starship Flight Tests Human Spaceflight Space Station Resupply Science Commercial / International Rideshare Program National Security Starlink Direct to Cell Starman | Vehicle Clear Falcon 9 Falcon Heavy Starship Falcon 1 | Launch Site Clear LC-39A, Florida SLC-40, Florida SLC-4E, California Starbase, Texas Omelek Island | Return Site Clear Droneship Landing Zone Mechazilla Expended Landing Zone / Expended Landing Zone / Droneship | Launch Date Clear 2025 2024 2023 2022 2021 2020 2019 2018 2017 2016 2015 2014 2013 2012 2011 2010 2009 2008 2007 2006 | | Starlink Mission | Falcon 9 | SLC-40, Florida | Droneship | July 29, 2025 | | Starlink Mission | Falcon 9 | SLC-40, Florida | Droneship | July 26, 2025 |\', \'score\': 0.98531}, {\'title\': \'Launch Schedule - Spaceflight Now\', \'url\': \'https://spaceflightnow.com/launch-schedule/\', \'content\': \'*   [[ August 10, 2025 ] SpaceX launches Amazon’s Project Kuiper satellites on fifth scheduled attempt Falcon 9](https://spaceflightnow.com/2025/08/10/live-coverage-spacex-falcon-9-to-make-another-attempt-to-launch-amazon-project-kuiper-mission/ "SpaceX launches Amazon’s Project Kuiper satellites on fifth scheduled attempt") A SpaceX Falcon 9 rocket will launch the eighth mission of the X-37B Orbital Test Vehicle (OTV-8), a cargo spaceplane built by Boeing on behalf of the U.S. Space Force in cooperation with the Air Force Rapid Capabilities Office. A SpaceX Falcon 9 rocket will launch a Cygnus spacecraft from Northrop Grumman on a resupply mission to the International Space Station. *   Image 3SpaceX launches 28 Starlink satellites on Falcon 9 rocket from Cape Canaveral August 14, 2025   *   Image 4ULA launches Vulcan rocket on first Space Force mission August 13, 2025  \', \'score\': 0.98529}, {\'title\': \'SpaceX Launch Schedule - RocketLaunch.Live\', \'url\': \'https://www.rocketlaunch.live/?filter=spacex\', \'content\': \'*   - [x] CAS Space   *   - [x] i-Space   *   - [x] Xichang Satellite Launch Center   *   - [x] Taiyuan Satellite Launch Center   *   - [x] Jiuquan Satellite Launch Center   *   - [x] Wenchang Satellite Launch Center   *   - [x] Space One   *   - [x] Astra Space   *    North Korea - [x] Sohae Satellite Launching Station   *    MAR 31  Starlink-243 (6-80) Mission (Falcon 9)")   *    MAR 26  Starlink-242 (11-7) Mission (Falcon 9)")   *    MAR 18  Starlink-241 (12-25) Mission (Falcon 9)")   *    MAR 15  Starlink-240 (12-16) Mission (Falcon 9)")   *    MAR 13  Starlink-239 (12-21) Mission (Falcon 9)")   *    MAR 03  Starlink-238 (12-20) Mission (Falcon 9)")   Mission The mission will also launch the FLIP lunar rover.") #### GO-1 Mission")\', \'score\': 0.98351}, {\'title\': \'Next Spaceflight | Rocket Launch Schedule\', \'url\': \'https://nextspaceflight.com/\', \'content\': \'Next Spaceflight | Rocket Launch Schedule ##### Long March 4C | Unknown Payload Sun Aug 17, 2025 09:05 UTC LC-3, Xichang Satellite Launch Center, China  Sun Aug 17, 2025 14:15 UTC LC-9A, Taiyuan Satellite Launch Center, China ...
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--5a6fed4f-fb45-43bf-8bbf-e1a87f81de63')}, 'run_id': '5a6fed4f-fb45-43bf-8bbf-e1a87f81de63', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:769e4a0d-44bf-b14e-e232-f568dd28fce1', 'checkpoint_ns': 'model:769e4a0d-44bf-b14e-e232-f568dd28fce1', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['258b23b8-bd07-4892-83f3-19ca8db2202a', 'd630df8b-895b-44d6-821e-89e14a14c988']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='The', additional_kwargs={}, response_metadata={}, id='run--5a6fed4f-fb45-43bf-8bbf-e1a87f81de63')}, 'run_id': '5a6fed4f-fb45-43bf-8bbf-e1a87f81de63', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:769e4a0d-44bf-b14e-e232-f568dd28fce1', 'checkpoint_ns': 'model:769e4a0d-44bf-b14e-e232-f568dd28fce1', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['258b23b8-bd07-4892-83f3-19ca8db2202a', 'd630df8b-895b-44d6-821e-89e14a14c988']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' next', additional_kwargs={}, response_metadata={}, id='run--5a6fed4f-fb45-43bf-8bbf-e1a87f81de63')}, 'run_id': '5a6fed4f-fb45-43bf-8bbf-e1a87f81de63', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:769e4a0d-44bf-b14e-e232-f568dd28fce1', 'checkpoint_ns': 'model:769e4a0d-44bf-b14e-e232-f568dd28fce1', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['258b23b8-bd07-4892-83f3-19ca8db2202a', 'd630df8b-895b-44d6-821e-89e14a14c988']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' SpaceX', additional_kwargs={}, response_metadata={}, id='run--5a6fed4f-fb45-43bf-8bbf-e1a87f81de63')}, 'run_id': '5a6fed4f-fb45-43bf-8bbf-e1a87f81de63', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:769e4a0d-44bf-b14e-e232-f568dd28fce1', 'checkpoint_ns': 'model:769e4a0d-44bf-b14e-e232-f568dd28fce1', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['258b23b8-bd07-4892-83f3-19ca8db2202a', 'd630df8b-895b-44d6-821e-89e14a14c988']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' launch', additional_kwargs={}, response_metadata={}, id='run--5a6fed4f-fb45-43bf-8bbf-e1a87f81de63')}, 'run_id': '5a6fed4f-fb45-43bf-8bbf-e1a87f81de63', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:769e4a0d-44bf-b14e-e232-f568dd28fce1', 'checkpoint_ns': 'model:769e4a0d-44bf-b14e-e232-f568dd28fce1', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['258b23b8-bd07-4892-83f3-19ca8db2202a', 'd630df8b-895b-44d6-821e-89e14a14c988']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' is', additional_kwargs={}, response_metadata={}, id='run--5a6fed4f-fb45-43bf-8bbf-e1a87f81de63')}, 'run_id': '5a6fed4f-fb45-43bf-8bbf-e1a87f81de63', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:769e4a0d-44bf-b14e-e232-f568dd28fce1', 'checkpoint_ns': 'model:769e4a0d-44bf-b14e-e232-f568dd28fce1', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['258b23b8-bd07-4892-83f3-19ca8db2202a', 'd630df8b-895b-44d6-821e-89e14a14c988']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' scheduled', additional_kwargs={}, response_metadata={}, id='run--5a6fed4f-fb45-43bf-8bbf-e1a87f81de63')}, 'run_id': '5a6fed4f-fb45-43bf-8bbf-e1a87f81de63', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:769e4a0d-44bf-b14e-e232-f568dd28fce1', 'checkpoint_ns': 'model:769e4a0d-44bf-b14e-e232-f568dd28fce1', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['258b23b8-bd07-4892-83f3-19ca8db2202a', 'd630df8b-895b-44d6-821e-89e14a14c988']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' for', additional_kwargs={}, response_metadata={}, id='run--5a6fed4f-fb45-43bf-8bbf-e1a87f81de63')}, 'run_id': '5a6fed4f-fb45-43bf-8bbf-e1a87f81de63', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:769e4a0d-44bf-b14e-e232-f568dd28fce1', 'checkpoint_ns': 'model:769e4a0d-44bf-b14e-e232-f568dd28fce1', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['258b23b8-bd07-4892-83f3-19ca8db2202a', 'd630df8b-895b-44d6-821e-89e14a14c988']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' August', additional_kwargs={}, response_metadata={}, id='run--5a6fed4f-fb45-43bf-8bbf-e1a87f81de63')}, 'run_id': '5a6fed4f-fb45-43bf-8bbf-e1a87f81de63', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:769e4a0d-44bf-b14e-e232-f568dd28fce1', 'checkpoint_ns': 'model:769e4a0d-44bf-b14e-e232-f568dd28fce1', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['258b23b8-bd07-4892-83f3-19ca8db2202a', 'd630df8b-895b-44d6-821e-89e14a14c988']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--5a6fed4f-fb45-43bf-8bbf-e1a87f81de63')}, 'run_id': '5a6fed4f-fb45-43bf-8bbf-e1a87f81de63', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:769e4a0d-44bf-b14e-e232-f568dd28fce1', 'checkpoint_ns': 'model:769e4a0d-44bf-b14e-e232-f568dd28fce1', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['258b23b8-bd07-4892-83f3-19ca8db2202a', 'd630df8b-895b-44d6-821e-89e14a14c988']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='10', additional_kwargs={}, response_metadata={}, id='run--5a6fed4f-fb45-43bf-8bbf-e1a87f81de63')}, 'run_id': '5a6fed4f-fb45-43bf-8bbf-e1a87f81de63', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:769e4a0d-44bf-b14e-e232-f568dd28fce1', 'checkpoint_ns': 'model:769e4a0d-44bf-b14e-e232-f568dd28fce1', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['258b23b8-bd07-4892-83f3-19ca8db2202a', 'd630df8b-895b-44d6-821e-89e14a14c988']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--5a6fed4f-fb45-43bf-8bbf-e1a87f81de63')}, 'run_id': '5a6fed4f-fb45-43bf-8bbf-e1a87f81de63', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:769e4a0d-44bf-b14e-e232-f568dd28fce1', 'checkpoint_ns': 'model:769e4a0d-44bf-b14e-e232-f568dd28fce1', 'ls_provider': 'groq', 'ls_model_name': 'llama-3.1-8b-instant', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['258b23b8-bd07-4892-83f3-19ca8db2202a', 'd630df8b-895b-44d6-821e-89e14a14c988']}
# ...
# {'event': 'on_chain_end', 'data': {'output': '__end__', 'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='fe8793a6-dc65-4160-86d3-667da7016618'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'abjfjmx2m', 'function': {'arguments': '{"query":"spacex next launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_46fc01befd', 'service_tier': 'on_demand'}, id='run--1e2fe9ea-b8f2-4c19-83f3-3aece3f121eb', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'spacex next launch date'}, 'id': 'abjfjmx2m', 'type': 'tool_call'}], usage_metadata={'input_tokens': 286, 'output_tokens': 23, 'total_tokens': 309}), ToolMessage(content='[{\'title\': \'SpaceX - Launches\', \'url\': \'https://www.spacex.com/launches/\', \'content\': \'| Mission Clear Starship Flight Tests Human Spaceflight Space Station Resupply Science Commercial / International Rideshare Program National Security Starlink Direct to Cell Starman | Vehicle Clear Falcon 9 Falcon Heavy Starship Falcon 1 | Launch Site Clear LC-39A, Florida SLC-40, Florida SLC-4E, California Starbase, Texas Omelek Island | Return Site Clear Droneship Landing Zone Mechazilla Expended Landing Zone / Expended Landing Zone / Droneship | Launch Date Clear 2025 2024 2023 2022 2021 2020 2019 2018 2017 2016 2015 2014 2013 2012 2011 2010 2009 2008 2007 2006 | | Starlink Mission | Falcon 9 | SLC-40, Florida | Droneship | July 29, 2025 | | Starlink Mission | Falcon 9 | SLC-40, Florida | Droneship | July 26, 2025 |\', \'score\': 0.98531}, {\'title\': \'Launch Schedule - Spaceflight Now\', \'url\': \'https://spaceflightnow.com/launch-schedule/\', \'content\': \'*   [[ August 10, 2025 ] SpaceX launches Amazon’s Project Kuiper satellites on fifth scheduled attempt Falcon 9](https://spaceflightnow.com/2025/08/10/live-coverage-spacex-falcon-9-to-make-another-attempt-to-launch-amazon-project-kuiper-mission/ "SpaceX launches Amazon’s Project Kuiper satellites on fifth scheduled attempt") A SpaceX Falcon 9 rocket will launch the eighth mission of the X-37B Orbital Test Vehicle (OTV-8), a cargo spaceplane built by Boeing on behalf of the U.S. Space Force in cooperation with the Air Force Rapid Capabilities Office. A SpaceX Falcon 9 rocket will launch a Cygnus spacecraft from Northrop Grumman on a resupply mission to the International Space Station. *   Image 3SpaceX launches 28 Starlink satellites on Falcon 9 rocket from Cape Canaveral August 14, 2025   *   Image 4ULA launches Vulcan rocket on first Space Force mission August 13, 2025  \', \'score\': 0.98529}, {\'title\': \'SpaceX Launch Schedule - RocketLaunch.Live\', \'url\': \'https://www.rocketlaunch.live/?filter=spacex\', \'content\': \'*   - [x] CAS Space   *   - [x] i-Space   *   - [x] Xichang Satellite Launch Center   *   - [x] Taiyuan Satellite Launch Center   *   - [x] Jiuquan Satellite Launch Center   *   - [x] Wenchang Satellite Launch Center   *   - [x] Space One   *   - [x] Astra Space   *    North Korea - [x] Sohae Satellite Launching Station   *    MAR 31  Starlink-243 (6-80) Mission (Falcon 9)")   *    MAR 26  Starlink-242 (11-7) Mission (Falcon 9)")   *    MAR 18  Starlink-241 (12-25) Mission (Falcon 9)")   *    MAR 15  Starlink-240 (12-16) Mission (Falcon 9)")   *    MAR 13  Starlink-239 (12-21) Mission (Falcon 9)")   *    MAR 03  Starlink-238 (12-20) Mission (Falcon 9)")   Mission The mission will also launch the FLIP lunar rover.") #### GO-1 Mission")\', \'score\': 0.98351}, {\'title\': \'Next Spaceflight | Rocket Launch Schedule\', \'url\': \'https://nextspaceflight.com/\', \'content\': \'Next Spaceflight | Rocket Launch Schedule ##### Long March 4C | Unknown Payload Sun Aug 17, 2025 09:05 UTC LC-3, Xichang Satellite Launch Center, China  Sun Aug 17, 2025 14:15 UTC LC-9A, Taiyuan Satellite Launch  ...
# {'event': 'on_chain_stream', 'run_id': 'd630df8b-895b-44d6-821e-89e14a14c988', 'name': 'model', 'tags': ['graph:step:3'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:769e4a0d-44bf-b14e-e232-f568dd28fce1'}, 'data': {'chunk': {'messages': [AIMessage(content="The next SpaceX launch is scheduled for August 10, 2025, which will be the fifth attempt to launch Amazon's Project Kuiper satellites on a Falcon 9 rocket.", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_510c177af0', 'service_tier': 'on_demand'}, id='run--5a6fed4f-fb45-43bf-8bbf-e1a87f81de63', usage_metadata={'input_tokens': 1361, 'output_tokens': 37, 'total_tokens': 1398})]}}, 'parent_ids': ['258b23b8-bd07-4892-83f3-19ca8db2202a']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [AIMessage(content="The next SpaceX launch is scheduled for August 10, 2025, which will be the fifth attempt to launch Amazon's Project Kuiper satellites on a Falcon 9 rocket.", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_510c177af0', 'service_tier': 'on_demand'}, id='run--5a6fed4f-fb45-43bf-8bbf-e1a87f81de63', usage_metadata={'input_tokens': 1361, 'output_tokens': 37, 'total_tokens': 1398})]}, 'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='fe8793a6-dc65-4160-86d3-667da7016618'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'abjfjmx2m', 'function': {'arguments': '{"query":"spacex next launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_46fc01befd', 'service_tier': 'on_demand'}, id='run--1e2fe9ea-b8f2-4c19-83f3-3aece3f121eb', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'spacex next launch date'}, 'id': 'abjfjmx2m', 'type': 'tool_call'}], usage_metadata={'input_tokens': 286, 'output_tokens': 23, 'total_tokens': 309}), ToolMessage(content='[{\'title\': \'SpaceX - Launches\', \'url\': \'https://www.spacex.com/launches/\', \'content\': \'| Mission Clear Starship Flight Tests Human Spaceflight Space Station Resupply Science Commercial / International Rideshare Program National Security Starlink Direct to Cell Starman | Vehicle Clear Falcon 9 Falcon Heavy Starship Falcon 1 | Launch Site Clear LC-39A, Florida SLC-40, Florida SLC-4E, California Starbase, Texas Omelek Island | Return Site Clear Droneship Landing Zone Mechazilla Expended Landing Zone / Expended Landing Zone / Droneship | Launch Date Clear 2025 2024 2023 2022 2021 2020 2019 2018 2017 2016 2015 2014 2013 2012 2011 2010 2009 2008 2007 2006 | | Starlink Mission | Falcon 9 | SLC-40, Florida | Droneship | July 29, 2025 | | Starlink Mission | Falcon 9 | SLC-40, Florida | Droneship | July 26, 2025 |\', \'score\': 0.98531}, {\'title\': \'Launch Schedule - Spaceflight Now\', \'url\': \'https://spaceflightnow.com/launch-schedule/\', \'content\': \'*   [[ August 10, 2025 ] SpaceX launches Amazon’s Project Kuiper satellites on fifth scheduled attempt Falcon 9](https://spaceflightnow.com/2025/08/10/live-coverage-spacex-falcon-9-to-make-another-attempt-to-launch-amazon-project-kuiper-mission/ "SpaceX launches Amazon’s Project Kuiper satellites on fifth scheduled attempt") A SpaceX Falcon 9 rocket will launch the eighth mission of the X-37B Orbital Test Vehicle (OTV-8), a cargo spaceplane built by Boeing on behalf of the U.S. Space Force in cooperation with the Air Force Rapid Capabilities Office. A SpaceX Falcon 9 rocket will launch a Cygnus spacecraft from Northrop Grumman on a resupply mission to the International Space Station. *   Image 3SpaceX launches 28 Starlink satellites on Falcon 9 rocket from Cape Canaveral August 14, 2025   *   Image 4ULA launches Vulcan rocket on first Space Force mission August 13, 2025  \', \'score\': 0.98529}, {\'title\': \'SpaceX Launch Schedule - RocketLaunch.Live\', \'url\': \'https://www.rocketlaunch.live/?filter=spacex\', \'content\': \'*   - [x] CAS Space   *   - [x] i-Space   *   - [x] Xichang Satellite Launch Center   *   - [x] Taiyuan Satellite Launch Center   *   - [x] Jiuquan Satellite Launch Center   *   - [x] Wenchang Satellite Launch Center   *   - [x] Space One   *   - [x] Astra Space   *    North Korea - [x] Sohae Satellite Launching Station   *    MAR 31  Starlink-243 (6-80) Mission (Falcon 9)")   *    MAR 26  Starlink-242 (11-7) Mission (Falcon 9)")   *    MAR 18  Starlink-241 (12-25) Mission (Falcon 9)")   *    MAR 15  Starlink-240 (12-16) Mission (Falcon 9)")   *    MAR 13  Starlink-239 (12-21) Mission (Falcon 9)")   *     ...
# {'event': 'on_chain_stream', 'run_id': '258b23b8-bd07-4892-83f3-19ca8db2202a', 'name': 'LangGraph', 'tags': [], 'metadata': {'thread_id': 8, 'LANGSMITH_TRACING': 'true', 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'LANGSMITH_PROJECT': 'pr-impressionable-lung-64'}, 'data': {'chunk': {'model': {'messages': [AIMessage(content="The next SpaceX launch is scheduled for August 10, 2025, which will be the fifth attempt to launch Amazon's Project Kuiper satellites on a Falcon 9 rocket.", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_510c177af0', 'service_tier': 'on_demand'}, id='run--5a6fed4f-fb45-43bf-8bbf-e1a87f81de63', usage_metadata={'input_tokens': 1361, 'output_tokens': 37, 'total_tokens': 1398})]}}}, 'parent_ids': []}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='fe8793a6-dc65-4160-86d3-667da7016618'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'abjfjmx2m', 'function': {'arguments': '{"query":"spacex next launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_46fc01befd', 'service_tier': 'on_demand'}, id='run--1e2fe9ea-b8f2-4c19-83f3-3aece3f121eb', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'spacex next launch date'}, 'id': 'abjfjmx2m', 'type': 'tool_call'}], usage_metadata={'input_tokens': 286, 'output_tokens': 23, 'total_tokens': 309}), ToolMessage(content='[{\'title\': \'SpaceX - Launches\', \'url\': \'https://www.spacex.com/launches/\', \'content\': \'| Mission Clear Starship Flight Tests Human Spaceflight Space Station Resupply Science Commercial / International Rideshare Program National Security Starlink Direct to Cell Starman | Vehicle Clear Falcon 9 Falcon Heavy Starship Falcon 1 | Launch Site Clear LC-39A, Florida SLC-40, Florida SLC-4E, California Starbase, Texas Omelek Island | Return Site Clear Droneship Landing Zone Mechazilla Expended Landing Zone / Expended Landing Zone / Droneship | Launch Date Clear 2025 2024 2023 2022 2021 2020 2019 2018 2017 2016 2015 2014 2013 2012 2011 2010 2009 2008 2007 2006 | | Starlink Mission | Falcon 9 | SLC-40, Florida | Droneship | July 29, 2025 | | Starlink Mission | Falcon 9 | SLC-40, Florida | Droneship | July 26, 2025 |\', \'score\': 0.98531}, {\'title\': \'Launch Schedule - Spaceflight Now\', \'url\': \'https://spaceflightnow.com/launch-schedule/\', \'content\': \'*   [[ August 10, 2025 ] SpaceX launches Amazon’s Project Kuiper satellites on fifth scheduled attempt Falcon 9](https://spaceflightnow.com/2025/08/10/live-coverage-spacex-falcon-9-to-make-another-attempt-to-launch-amazon-project-kuiper-mission/ "SpaceX launches Amazon’s Project Kuiper satellites on fifth scheduled attempt") A SpaceX Falcon 9 rocket will launch the eighth mission of the X-37B Orbital Test Vehicle (OTV-8), a cargo spaceplane built by Boeing on behalf of the U.S. Space Force in cooperation with the Air Force Rapid Capabilities Office. A SpaceX Falcon 9 rocket will launch a Cygnus spacecraft from Northrop Grumman on a resupply mission to the International Space Station. *   Image 3SpaceX launches 28 Starlink satellites on Falcon 9 rocket from Cape Canaveral August 14, 2025   *   Image 4ULA launches Vulcan rocket on first Space Force mission August 13, 2025  \', \'score\': 0.98529}, {\'title\': \'SpaceX Launch Schedule - RocketLaunch.Live\', \'url\': \'https://www.rocketlaunch.live/?filter=spacex\', \'content\': \'*   - [x] CAS Space   *   - [x] i-Space   *   - [x] Xichang Satellite Launch Center   *   - [x] Taiyuan Satellite Launch Center   *   - [x] Jiuquan Satellite Launch Center   *   - [x] Wenchang Satellite Launch Center   *   - [x] Space One   *   - [x] Astra Space   *    North Korea - [x] Sohae Satellite Launching Station   *    MAR 31  Starlink-243 (6-80) Mission (Falcon 9)")   *    MAR 26  Starlink-242 (11-7) Mission (Falcon 9)")   *    MAR 18  Starlink-241 (12-25) Mission (Falcon 9)")   *    MAR 15  Starlink-240 (12-16) Mission (Falcon 9)")   *    MAR 13  Starlink-239 (12-21) Mission (Falcon 9)")   *    MAR 03  Starlink-238 (12-20) Mission (Falcon 9)")   Mission The mission will also launch the FLIP lunar rover.") #### GO-1 Mission")\', \'score\': 0.98351}, {\'title\': \'Next Spaceflight | Rocket Launch Schedule\', \'url\': \'https://nextspaceflight.com/\', \'content\': \'Next Spaceflight | Rocket Launch Schedule ##### Long March 4C | Unknown Payload Sun Aug 17, 2025 09:05 UTC LC-3, Xichang Satellite Launch Center, China  Sun Aug 17, 2025 14:15 UTC LC-9A, Taiyuan Satellite Launch Center, China  Mon A ...
